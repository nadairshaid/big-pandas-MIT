# %% [markdown]
# <a href="https://colab.research.google.com/github/nadairshaid/big-pandas-MIT/blob/decision_tree/Decision_Tree_Hackathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing and Mounting**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Libraries to help with reading and manipulating data
import pandas as pd
import numpy as np

# Libaries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Removes the limit for the number of displayed columns
pd.set_option("display.max_columns", None)
# Sets the limit for the number of displayed rows
pd.set_option("display.max_rows", 200)
# Setting the precision of floating numbers to 5 decimal points
pd.set_option("display.float_format", lambda x: "%.5f" % x)

# To tune model, get different metric scores, and split data
from sklearn.metrics import (
    f1_score,
    accuracy_score,
    recall_score,
    precision_score,
    confusion_matrix,
    roc_auc_score,
    plot_confusion_matrix,
    classification_report,
    precision_recall_curve
)
from sklearn import metrics

from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score

# To be used for data scaling and one hot encoding
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder

# To impute missing values
from sklearn.impute import SimpleImputer

# To help with model building
from sklearn.linear_model import LogisticRegression

# To build classification models 
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression


# For tuning the model
from sklearn.model_selection import GridSearchCV

# To supress warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#Importing data
survey_train = pd.read_csv('/content/drive/MyDrive/MITHackathon/Surveydata_train.csv') 
survey_test = pd.read_csv('/content/drive/MyDrive/MITHackathon/Surveydata_test.csv') 
travel_train = pd.read_csv('/content/drive/MyDrive/MITHackathon/Traveldata_train.csv') 
travel_test = pd.read_csv('/content/drive/MyDrive/MITHackathon/Traveldata_test.csv')

# %% [markdown]
# **Getting Info**

# %%
survey_train.shape
# Out:
# (94379, 17)

# %%
survey_train.head()
# Out:
#          ID  Overall_Experience       Seat_Comfort Seat_Class  \
# 0  98800001                   0  Needs Improvement  Green Car
# 1  98800002                   0               Poor   Ordinary
# 2  98800003                   1  Needs Improvement  Green Car
# 3  98800004                   0         Acceptable   Ordinary
# 4  98800005                   1         Acceptable   Ordinary
#
#   Arrival_Time_Convenient           Catering  Platform_Location  \
# 0               Excellent          Excellent    Very Convenient
# 1               Excellent               Poor  Needs Improvement
# 2       Needs Improvement  Needs Improvement  Needs Improvement
# 3       Needs Improvement                NaN  Needs Improvement
# 4              Acceptable         Acceptable         Manageable
#
#   Onboard_Wifi_Service Onboard_Entertainment Online_Support  \
# 0                 Good     Needs Improvement     Acceptable
# 1                 Good                  Poor           Good
# 2    Needs Improvement                  Good      Excellent
# 3           Acceptable     Needs Improvement     Acceptable
# 4    Needs Improvement                  Good      Excellent
#
#   Ease_of_Online_Booking    Onboard_Service            Legroom  \
# 0      Needs Improvement  Needs Improvement         Acceptable
# 1                   Good          Excellent  Needs Improvement
# 2              Excellent          Excellent          Excellent
# 3             Acceptable         Acceptable         Acceptable
# 4                   Good               Good               Good
#
#     Baggage_Handling    CheckIn_Service        Cleanliness Online_Boarding
# 0  Needs Improvement               Good  Needs Improvement            Poor
# 1               Poor  Needs Improvement               Good            Good
# 2          Excellent               Good          Excellent       Excellent
# 3         Acceptable               Good         Acceptable      Acceptable
# 4               Good               Good               Good            Good

# %%
survey_train.tail()
# Out:
#              ID  Overall_Experience       Seat_Comfort Seat_Class  \
# 94374  98894375                   0               Poor   Ordinary
# 94375  98894376                   1               Good   Ordinary
# 94376  98894377                   1  Needs Improvement  Green Car
# 94377  98894378                   0  Needs Improvement   Ordinary
# 94378  98894379                   0         Acceptable   Ordinary
#
#       Arrival_Time_Convenient           Catering  Platform_Location  \
# 94374                    Good               Good         Convenient
# 94375                    Good               Good         Convenient
# 94376       Needs Improvement  Needs Improvement  Needs Improvement
# 94377                     NaN  Needs Improvement         Convenient
# 94378                    Poor         Acceptable         Manageable
#
#       Onboard_Wifi_Service Onboard_Entertainment Online_Support  \
# 94374                 Poor                  Poor           Poor
# 94375    Needs Improvement             Excellent      Excellent
# 94376                 Good             Excellent           Good
# 94377                 Good     Needs Improvement           Good
# 94378           Acceptable            Acceptable     Acceptable
#
#       Ease_of_Online_Booking Onboard_Service     Legroom Baggage_Handling  \
# 94374                   Poor            Good        Good             Good
# 94375             Acceptable      Acceptable  Acceptable       Acceptable
# 94376                   Good            Good        Good             Good
# 94377                   Good      Acceptable        Good             Good
# 94378             Acceptable            Poor        Good             Good
#
#          CheckIn_Service Cleanliness Online_Boarding
# 94374  Needs Improvement        Good            Poor
# 94375               Good  Acceptable            Good
# 94376         Acceptable        Good      Acceptable
# 94377               Good   Excellent            Good
# 94378               Poor        Good      Acceptable

# %%
survey_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94379 entries, 0 to 94378
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       94379 non-null  int64
#  1   Overall_Experience       94379 non-null  int64
#  2   Seat_Comfort             94318 non-null  object
#  3   Seat_Class               94379 non-null  object
#  4   Arrival_Time_Convenient  85449 non-null  object
#  5   Catering                 85638 non-null  object
#  6   Platform_Location        94349 non-null  object
#  7   Onboard_Wifi_Service     94349 non-null  object
#  8   Onboard_Entertainment    94361 non-null  object
#  9   Online_Support           94288 non-null  object
#  10  Ease_of_Online_Booking   94306 non-null  object
#  11  Onboard_Service          86778 non-null  object
#  12  Legroom                  94289 non-null  object
#  13  Baggage_Handling         94237 non-null  object
#  14  CheckIn_Service          94302 non-null  object
#  15  Cleanliness              94373 non-null  object
#  16  Online_Boarding          94373 non-null  object
# dtypes: int64(2), object(15)
# memory usage: 12.2+ MB

# %%
travel_train.shape
# Out:
# (94379, 9)

# %%
travel_train.head()
# Out:
#          ID  Gender   Customer_Type      Age      Type_Travel Travel_Class  \
# 0  98800001  Female  Loyal Customer 52.00000              NaN     Business
# 1  98800002    Male  Loyal Customer 48.00000  Personal Travel          Eco
# 2  98800003  Female  Loyal Customer 43.00000  Business Travel     Business
# 3  98800004  Female  Loyal Customer 44.00000  Business Travel     Business
# 4  98800005  Female  Loyal Customer 50.00000  Business Travel     Business
#
#    Travel_Distance  Departure_Delay_in_Mins  Arrival_Delay_in_Mins
# 0              272                  0.00000                5.00000
# 1             2200                  9.00000                0.00000
# 2             1061                 77.00000              119.00000
# 3              780                 13.00000               18.00000
# 4             1981                  0.00000                0.00000

# %%
travel_train.tail()
# Out:
#              ID Gender   Customer_Type      Age      Type_Travel Travel_Class  \
# 94374  98894375   Male  Loyal Customer 32.00000  Business Travel     Business
# 94375  98894376   Male  Loyal Customer 44.00000  Business Travel     Business
# 94376  98894377   Male             NaN 63.00000  Business Travel     Business
# 94377  98894378   Male  Loyal Customer 16.00000  Personal Travel          Eco
# 94378  98894379   Male  Loyal Customer 54.00000              NaN          Eco
#
#        Travel_Distance  Departure_Delay_in_Mins  Arrival_Delay_in_Mins
# 94374             1357                 83.00000              125.00000
# 94375              592                  5.00000               11.00000
# 94376             2794                  0.00000                0.00000
# 94377             2744                  0.00000                0.00000
# 94378             2107                 28.00000               28.00000

# %%
travel_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94379 entries, 0 to 94378
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       94379 non-null  int64
#  1   Gender                   94302 non-null  object
#  2   Customer_Type            85428 non-null  object
#  3   Age                      94346 non-null  float64
#  4   Type_Travel              85153 non-null  object
#  5   Travel_Class             94379 non-null  object
#  6   Travel_Distance          94379 non-null  int64
#  7   Departure_Delay_in_Mins  94322 non-null  float64
#  8   Arrival_Delay_in_Mins    94022 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 6.5+ MB

# %% [markdown]
# **Merging Data Frames**

# %%
df = travel_train.merge(survey_train, how='outer', on= 'ID', indicator= True)

# %%
df
# Out:
#              ID  Gender   Customer_Type      Age      Type_Travel  \
# 0      98800001  Female  Loyal Customer 52.00000              NaN
# 1      98800002    Male  Loyal Customer 48.00000  Personal Travel
# 2      98800003  Female  Loyal Customer 43.00000  Business Travel
# 3      98800004  Female  Loyal Customer 44.00000  Business Travel
# 4      98800005  Female  Loyal Customer 50.00000  Business Travel
# ...         ...     ...             ...      ...              ...
# 94374  98894375    Male  Loyal Customer 32.00000  Business Travel
# 94375  98894376    Male  Loyal Customer 44.00000  Business Travel
# 94376  98894377    Male             NaN 63.00000  Business Travel
# 94377  98894378    Male  Loyal Customer 16.00000  Personal Travel
# 94378  98894379    Male  Loyal Customer 54.00000              NaN
#
#       Travel_Class  Travel_Distance  Departure_Delay_in_Mins  \
# 0         Business              272                  0.00000
# 1              Eco             2200                  9.00000
# 2         Business             1061                 77.00000
# 3         Business              780                 13.00000
# 4         Business             1981                  0.00000
# ...            ...              ...                      ...
# 94374     Business             1357                 83.00000
# 94375     Business              592                  5.00000
# 94376     Business             2794                  0.00000
# 94377          Eco             2744                  0.00000
# 94378          Eco             2107                 28.00000
#
#        Arrival_Delay_in_Mins  Overall_Experience       Seat_Comfort  \
# 0                    5.00000                   0  Needs Improvement
# 1                    0.00000                   0               Poor
# 2                  119.00000                   1  Needs Improvement
# 3                   18.00000                   0         Acceptable
# 4                    0.00000                   1         Acceptable
# ...                      ...                 ...                ...
# 94374              125.00000                   0               Poor
# 94375               11.00000                   1               Good
# 94376                0.00000                   1  Needs Improvement
# 94377                0.00000                   0  Needs Improvement
# 94378               28.00000                   0         Acceptable
#
#       Seat_Class Arrival_Time_Convenient           Catering  \
# 0      Green Car               Excellent          Excellent
# 1       Ordinary               Excellent               Poor
# 2      Green Car       Needs Improvement  Needs Improvement
# 3       Ordinary       Needs Improvement                NaN
# 4       Ordinary              Acceptable         Acceptable
# ...          ...                     ...                ...
# 94374   Ordinary                    Good               Good
# 94375   Ordinary                    Good               Good
# 94376  Green Car       Needs Improvement  Needs Improvement
# 94377   Ordinary                     NaN  Needs Improvement
# 94378   Ordinary                    Poor         Acceptable
#
#        Platform_Location Onboard_Wifi_Service Onboard_Entertainment  \
# 0        Very Convenient                 Good     Needs Improvement
# 1      Needs Improvement                 Good                  Poor
# 2      Needs Improvement    Needs Improvement                  Good
# 3      Needs Improvement           Acceptable     Needs Improvement
# 4             Manageable    Needs Improvement                  Good
# ...                  ...                  ...                   ...
# 94374         Convenient                 Poor                  Poor
# 94375         Convenient    Needs Improvement             Excellent
# 94376  Needs Improvement                 Good             Excellent
# 94377         Convenient                 Good     Needs Improvement
# 94378         Manageable           Acceptable            Acceptable
#
#       Online_Support Ease_of_Online_Booking    Onboard_Service  \
# 0         Acceptable      Needs Improvement  Needs Improvement
# 1               Good                   Good          Excellent
# 2          Excellent              Excellent          Excellent
# 3         Acceptable             Acceptable         Acceptable
# 4          Excellent                   Good               Good
# ...              ...                    ...                ...
# 94374           Poor                   Poor               Good
# 94375      Excellent             Acceptable         Acceptable
# 94376           Good                   Good               Good
# 94377           Good                   Good         Acceptable
# 94378     Acceptable             Acceptable               Poor
#
#                  Legroom   Baggage_Handling    CheckIn_Service  \
# 0             Acceptable  Needs Improvement               Good
# 1      Needs Improvement               Poor  Needs Improvement
# 2              Excellent          Excellent               Good
# 3             Acceptable         Acceptable               Good
# 4                   Good               Good               Good
# ...                  ...                ...                ...
# 94374               Good               Good  Needs Improvement
# 94375         Acceptable         Acceptable               Good
# 94376               Good               Good         Acceptable
# 94377               Good               Good               Good
# 94378               Good               Good               Poor
#
#              Cleanliness Online_Boarding _merge
# 0      Needs Improvement            Poor   both
# 1                   Good            Good   both
# 2              Excellent       Excellent   both
# 3             Acceptable      Acceptable   both
# 4                   Good            Good   both
# ...                  ...             ...    ...
# 94374               Good            Poor   both
# 94375         Acceptable            Good   both
# 94376               Good      Acceptable   both
# 94377          Excellent            Good   both
# 94378               Good      Acceptable   both
#
# [94379 rows x 26 columns]

# %%
df.replace(to_replace = "Poor", value = 1, inplace = True, regex = True, )
df.replace(to_replace = "Needs Improvement", value = 2, inplace = True, regex = True, )
df.replace(to_replace = "Acceptable", value = 3, inplace = True, regex = True, )
df.replace(to_replace = "Good", value = 4, inplace = True, regex = True, )
df.replace(to_replace = "Excellent", value = 5, inplace = True, regex = True, )


df.replace(to_replace = "Poor", value = 1, inplace = True, regex = True, )
df.replace(to_replace = "Inconvenient", value = 2, inplace = True, regex = True, )
df.replace(to_replace = "Manageable", value = 3, inplace = True, regex = True, )
df.replace(to_replace = "Convenient", value = 4, inplace = True, regex = True, )
df.replace(to_replace = "Very Convenient", value = 5, inplace = True, regex = True, )

# %%
df.head()
# Out:
#          ID  Gender   Customer_Type      Age      Type_Travel Travel_Class  \
# 0  98800001  Female  Loyal Customer 52.00000              NaN     Business
# 1  98800002    Male  Loyal Customer 48.00000  Personal Travel          Eco
# 2  98800003  Female  Loyal Customer 43.00000  Business Travel     Business
# 3  98800004  Female  Loyal Customer 44.00000  Business Travel     Business
# 4  98800005  Female  Loyal Customer 50.00000  Business Travel     Business
#
#    Travel_Distance  Departure_Delay_in_Mins  Arrival_Delay_in_Mins  \
# 0              272                  0.00000                5.00000
# 1             2200                  9.00000                0.00000
# 2             1061                 77.00000              119.00000
# 3              780                 13.00000               18.00000
# 4             1981                  0.00000                0.00000
#
#    Overall_Experience Seat_Comfort Seat_Class Arrival_Time_Convenient  \
# 0                   0            2  Green Car                       5
# 1                   0            1   Ordinary                       5
# 2                   1            2  Green Car                       2
# 3                   0            3   Ordinary                       2
# 4                   1            3   Ordinary                       3
#
#   Catering Platform_Location Onboard_Wifi_Service Onboard_Entertainment  \
# 0        5                 4                    4                     2
# 1        1                 2                    4                     1
# 2        2                 2                    2                     4
# 3      NaN                 2                    3                     2
# 4        3                 3                    2                     4
#
#   Online_Support Ease_of_Online_Booking Onboard_Service Legroom  \
# 0              3                      2               2       3
# 1              4                      4               5       2
# 2              5                      5               5       5
# 3              3                      3               3       3
# 4              5                      4               4       4
#
#   Baggage_Handling CheckIn_Service Cleanliness Online_Boarding _merge
# 0                2               4           2               1   both
# 1                1               2           4               4   both
# 2                5               4           5               5   both
# 3                3               4           3               3   both
# 4                4               4           4               4   both

# %%
df.index = [np.arange(98800001,98894380)]
df.head(15)
# Out:
#                 ID  Gender      Customer_Type      Age      Type_Travel  \
# 98800001  98800001  Female     Loyal Customer 52.00000              NaN
# 98800002  98800002    Male     Loyal Customer 48.00000  Personal Travel
# 98800003  98800003  Female     Loyal Customer 43.00000  Business Travel
# 98800004  98800004  Female     Loyal Customer 44.00000  Business Travel
# 98800005  98800005  Female     Loyal Customer 50.00000  Business Travel
# 98800006  98800006    Male     Loyal Customer 44.00000  Business Travel
# 98800007  98800007    Male     Loyal Customer 56.00000  Personal Travel
# 98800008  98800008    Male     Loyal Customer 65.00000  Personal Travel
# 98800009  98800009    Male     Loyal Customer 22.00000  Personal Travel
# 98800010  98800010    Male     Loyal Customer 57.00000  Business Travel
# 98800011  98800011  Female  Disloyal Customer 25.00000  Business Travel
# 98800012  98800012    Male     Loyal Customer 26.00000  Personal Travel
# 98800013  98800013    Male     Loyal Customer 44.00000              NaN
# 98800014  98800014  Female     Loyal Customer 47.00000  Personal Travel
# 98800015  98800015    Male     Loyal Customer 33.00000  Business Travel
#
#          Travel_Class  Travel_Distance  Departure_Delay_in_Mins  \
# 98800001     Business              272                  0.00000
# 98800002          Eco             2200                  9.00000
# 98800003     Business             1061                 77.00000
# 98800004     Business              780                 13.00000
# 98800005     Business             1981                  0.00000
# 98800006     Business             2810                  0.00000
# 98800007          Eco             2029                  0.00000
# 98800008     Business              853                  0.00000
# 98800009          Eco             1636                  1.00000
# 98800010     Business              306                  0.00000
# 98800011     Business             1761                  0.00000
# 98800012          Eco             1905                  0.00000
# 98800013     Business              427                  0.00000
# 98800014          Eco             1100                 20.00000
# 98800015     Business             1180                 49.00000
#
#           Arrival_Delay_in_Mins  Overall_Experience Seat_Comfort Seat_Class  \
# 98800001                5.00000                   0            2  Green Car
# 98800002                0.00000                   0            1   Ordinary
# 98800003              119.00000                   1            2  Green Car
# 98800004               18.00000                   0            3   Ordinary
# 98800005                0.00000                   1            3   Ordinary
# 98800006                0.00000                   1            2   Ordinary
# 98800007                0.00000                   0            4  Green Car
# 98800008                3.00000                   0            3  Green Car
# 98800009                0.00000                   0            2  Green Car
# 98800010                0.00000                   0            2   Ordinary
# 98800011                0.00000                   1            4  Green Car
# 98800012                0.00000                   1            4   Ordinary
# 98800013                0.00000                   1            3   Ordinary
# 98800014               34.00000                   0            4   Ordinary
# 98800015               49.00000                   0            3   Ordinary
#
#          Arrival_Time_Convenient Catering Platform_Location  \
# 98800001                       5        5                 4
# 98800002                       5        1                 2
# 98800003                       2        2                 2
# 98800004                       2      NaN                 2
# 98800005                       3        3                 3
# 98800006                       2        3                 2
# 98800007                       5        4                 2
# 98800008                     NaN        3                 2
# 98800009                       2        2                 2
# 98800010                       4        4                 4
# 98800011                       4        4                 2
# 98800012                       3        4                 2
# 98800013                     NaN        5                 3
# 98800014                       4        4                 3
# 98800015                       1        1                 2
#
#          Onboard_Wifi_Service Onboard_Entertainment Online_Support  \
# 98800001                    4                     2              3
# 98800002                    4                     1              4
# 98800003                    2                     4              5
# 98800004                    3                     2              3
# 98800005                    2                     4              5
# 98800006                    4                     5              4
# 98800007                    4                     4              4
# 98800008                    5                     5              4
# 98800009                    3                     2              3
# 98800010                    3                     4              4
# 98800011                    1                     4              1
# 98800012                    3                     4              3
# 98800013                    2                     4              5
# 98800014                    4                     5            NaN
# 98800015                    3                     3              3
#
#          Ease_of_Online_Booking Onboard_Service Legroom Baggage_Handling  \
# 98800001                      2               2       3                2
# 98800002                      4               5       2                1
# 98800003                      5               5       5                5
# 98800004                      3               3       3                3
# 98800005                      4               4       4                4
# 98800006                      3               3       4                3
# 98800007                      4               4       5                2
# 98800008                      4               4       3                4
# 98800009                      3               3       3                2
# 98800010                      2               2       2                2
# 98800011                      1               5       5                3
# 98800012                      3               2       5                2
# 98800013                      5               5       5                5
# 98800014                    NaN               3       4              NaN
# 98800015                      3               2       2                2
#
#          CheckIn_Service Cleanliness Online_Boarding _merge
# 98800001               4           2               1   both
# 98800002               2           4               4   both
# 98800003               4           5               5   both
# 98800004               4           3               3   both
# 98800005               4           4               4   both
# 98800006               3           3               3   both
# 98800007               5           3               4   both
# 98800008               4           4               5   both
# 98800009               3           2               3   both
# 98800010               3           2               3   both
# 98800011               4           4               1   both
# 98800012               1           1               3   both
# 98800013               4           5               4   both
# 98800014             NaN           3               4   both
# 98800015               4           2               3   both

# %%
df=df.drop(['_merge','ID'],axis=1)

# %%
df.head()
# Out:
#           Gender   Customer_Type      Age      Type_Travel Travel_Class  \
# 98800001  Female  Loyal Customer 52.00000              NaN     Business
# 98800002    Male  Loyal Customer 48.00000  Personal Travel          Eco
# 98800003  Female  Loyal Customer 43.00000  Business Travel     Business
# 98800004  Female  Loyal Customer 44.00000  Business Travel     Business
# 98800005  Female  Loyal Customer 50.00000  Business Travel     Business
#
#           Travel_Distance  Departure_Delay_in_Mins  Arrival_Delay_in_Mins  \
# 98800001              272                  0.00000                5.00000
# 98800002             2200                  9.00000                0.00000
# 98800003             1061                 77.00000              119.00000
# 98800004              780                 13.00000               18.00000
# 98800005             1981                  0.00000                0.00000
#
#           Overall_Experience Seat_Comfort Seat_Class Arrival_Time_Convenient  \
# 98800001                   0            2  Green Car                       5
# 98800002                   0            1   Ordinary                       5
# 98800003                   1            2  Green Car                       2
# 98800004                   0            3   Ordinary                       2
# 98800005                   1            3   Ordinary                       3
#
#          Catering Platform_Location Onboard_Wifi_Service  \
# 98800001        5                 4                    4
# 98800002        1                 2                    4
# 98800003        2                 2                    2
# 98800004      NaN                 2                    3
# 98800005        3                 3                    2
#
#          Onboard_Entertainment Online_Support Ease_of_Online_Booking  \
# 98800001                     2              3                      2
# 98800002                     1              4                      4
# 98800003                     4              5                      5
# 98800004                     2              3                      3
# 98800005                     4              5                      4
#
#          Onboard_Service Legroom Baggage_Handling CheckIn_Service Cleanliness  \
# 98800001               2       3                2               4           2
# 98800002               5       2                1               2           4
# 98800003               5       5                5               4           5
# 98800004               3       3                3               4           3
# 98800005               4       4                4               4           4
#
#          Online_Boarding
# 98800001               1
# 98800002               4
# 98800003               5
# 98800004               3
# 98800005               4

# %%
# Creating list of dummy columns
to_get_dummies_for = ['Gender', 'Customer_Type','Type_Travel', 'Travel_Class', ]

# Creating dummy variables
pd.get_dummies(data = df, columns = to_get_dummies_for, drop_first = True)      

# Mapping overtime and attrition
dict_Gender = {'Male': 1, 'Female':0}
dict_Customer_Type = {'Loyal Customer': 1, 'Disloyal Customer': 0}
dict_Type_Travel = {'Business Travel': 1, 'Personal Travel': 0}
dict_Travel_Class = {'Business': 1, 'Eco': 0}


df['Gender'] = df.Gender.map(dict_Gender)
df['Customer_Type'] = df.Customer_Type.map(dict_Customer_Type)
df['Type_Travel'] = df.Type_Travel.map(dict_Type_Travel)
df['Travel_Class'] = df.Travel_Class.map(dict_Travel_Class)
df['Seat_Class'] = df.Seat_Class.map(dict_Travel_Class)

# %%
Y= df.Overall_Experience
X= df.drop(columns = ['Overall_Experience'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = 1, stratify = Y)

# %%
df.fillna(df.median(),inplace = True)

# %%
# Creating metric function 
def metrics_score(actual, predicted):
    print(classification_report(actual, predicted))

    cm = confusion_matrix(actual, predicted)
    plt.figure(figsize=(8,5))
    
    sns.heatmap(cm, annot=True,  fmt='.2f', xticklabels=['Not Attrite', 'Attrite'], yticklabels=['Not Attrite', 'Attrite'])
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()

# %%
df
# Out:
#           Gender  Customer_Type      Age  Type_Travel  Travel_Class  \
# 98800001 0.00000        1.00000 52.00000      1.00000             1
# 98800002 1.00000        1.00000 48.00000      0.00000             0
# 98800003 0.00000        1.00000 43.00000      1.00000             1
# 98800004 0.00000        1.00000 44.00000      1.00000             1
# 98800005 0.00000        1.00000 50.00000      1.00000             1
# ...          ...            ...      ...          ...           ...
# 98894375 1.00000        1.00000 32.00000      1.00000             1
# 98894376 1.00000        1.00000 44.00000      1.00000             1
# 98894377 1.00000        1.00000 63.00000      1.00000             1
# 98894378 1.00000        1.00000 16.00000      0.00000             0
# 98894379 1.00000        1.00000 54.00000      1.00000             0
#
#           Travel_Distance  Departure_Delay_in_Mins  Arrival_Delay_in_Mins  \
# 98800001              272                  0.00000                5.00000
# 98800002             2200                  9.00000                0.00000
# 98800003             1061                 77.00000              119.00000
# 98800004              780                 13.00000               18.00000
# 98800005             1981                  0.00000                0.00000
# ...                   ...                      ...                    ...
# 98894375             1357                 83.00000              125.00000
# 98894376              592                  5.00000               11.00000
# 98894377             2794                  0.00000                0.00000
# 98894378             2744                  0.00000                0.00000
# 98894379             2107                 28.00000               28.00000
#
#           Overall_Experience  Seat_Comfort  Seat_Class  \
# 98800001                   0       2.00000         NaN
# 98800002                   0       1.00000         NaN
# 98800003                   1       2.00000         NaN
# 98800004                   0       3.00000         NaN
# 98800005                   1       3.00000         NaN
# ...                      ...           ...         ...
# 98894375                   0       1.00000         NaN
# 98894376                   1       4.00000         NaN
# 98894377                   1       2.00000         NaN
# 98894378                   0       2.00000         NaN
# 98894379                   0       3.00000         NaN
#
#           Arrival_Time_Convenient  Catering  Platform_Location  \
# 98800001                  5.00000   5.00000            4.00000
# 98800002                  5.00000   1.00000            2.00000
# 98800003                  2.00000   2.00000            2.00000
# 98800004                  2.00000   3.00000            2.00000
# 98800005                  3.00000   3.00000            3.00000
# ...                           ...       ...                ...
# 98894375                  4.00000   4.00000            4.00000
# 98894376                  4.00000   4.00000            4.00000
# 98894377                  2.00000   2.00000            2.00000
# 98894378                  3.00000   2.00000            4.00000
# 98894379                  1.00000   3.00000            3.00000
#
#           Onboard_Wifi_Service  Onboard_Entertainment  Online_Support  \
# 98800001               4.00000                2.00000         3.00000
# 98800002               4.00000                1.00000         4.00000
# 98800003               2.00000                4.00000         5.00000
# 98800004               3.00000                2.00000         3.00000
# 98800005               2.00000                4.00000         5.00000
# ...                        ...                    ...             ...
# 98894375               1.00000                1.00000         1.00000
# 98894376               2.00000                5.00000         5.00000
# 98894377               4.00000                5.00000         4.00000
# 98894378               4.00000                2.00000         4.00000
# 98894379               3.00000                3.00000         3.00000
#
#           Ease_of_Online_Booking  Onboard_Service  Legroom  Baggage_Handling  \
# 98800001                 2.00000          2.00000  3.00000           2.00000
# 98800002                 4.00000          5.00000  2.00000           1.00000
# 98800003                 5.00000          5.00000  5.00000           5.00000
# 98800004                 3.00000          3.00000  3.00000           3.00000
# 98800005                 4.00000          4.00000  4.00000           4.00000
# ...                          ...              ...      ...               ...
# 98894375                 1.00000          4.00000  4.00000           4.00000
# 98894376                 3.00000          3.00000  3.00000           3.00000
# 98894377                 4.00000          4.00000  4.00000           4.00000
# 98894378                 4.00000          3.00000  4.00000           4.00000
# 98894379                 3.00000          1.00000  4.00000           4.00000
#
#           CheckIn_Service  Cleanliness  Online_Boarding
# 98800001          4.00000      2.00000          1.00000
# 98800002          2.00000      4.00000          4.00000
# 98800003          4.00000      5.00000          5.00000
# 98800004          4.00000      3.00000          3.00000
# 98800005          4.00000      4.00000          4.00000
# ...                   ...          ...              ...
# 98894375          2.00000      4.00000          1.00000
# 98894376          4.00000      3.00000          4.00000
# 98894377          3.00000      4.00000          3.00000
# 98894378          4.00000      5.00000          4.00000
# 98894379          1.00000      4.00000          3.00000
#
# [94379 rows x 24 columns]

# %%
round(df.isnull().sum() / df.isnull().count() * 100, 2)
# Out:
# Gender                      0.00000
# Customer_Type               0.00000
# Age                         0.00000
# Type_Travel                 0.00000
# Travel_Class                0.00000
# Travel_Distance             0.00000
# Departure_Delay_in_Mins     0.00000
# Arrival_Delay_in_Mins       0.00000
# Overall_Experience          0.00000
# Seat_Comfort                0.00000
# Seat_Class                100.00000
# Arrival_Time_Convenient     0.00000
# Catering                    0.00000
# Platform_Location           0.00000
# Onboard_Wifi_Service        0.00000
# Onboard_Entertainment       0.00000
# Online_Support              0.00000
# Ease_of_Online_Booking      0.00000
# Onboard_Service             0.00000
# Legroom                     0.00000
# Baggage_Handling            0.00000
# CheckIn_Service             0.00000
# Cleanliness                 0.00000
# Online_Boarding             0.00000
# dtype: float64

# %% [markdown]
# **Decision Tree**

# %%
X_train
# Out:
#           Gender  Customer_Type      Age  Type_Travel  Travel_Class  \
# 98890113 1.00000        1.00000 49.00000      1.00000             1
# 98854259 0.00000        1.00000 45.00000      1.00000             1
# 98858137 1.00000        1.00000 25.00000          NaN             1
# 98823289 0.00000        0.00000 21.00000      1.00000             0
# 98831835 1.00000        0.00000 35.00000          NaN             1
# ...          ...            ...      ...          ...           ...
# 98807581 1.00000        1.00000 57.00000      1.00000             1
# 98886703 1.00000        1.00000 34.00000      1.00000             1
# 98836614 0.00000        1.00000 54.00000      1.00000             0
# 98800530 0.00000        1.00000 35.00000      1.00000             1
# 98868265 0.00000        1.00000 41.00000      1.00000             1
#
#           Travel_Distance  Departure_Delay_in_Mins  Arrival_Delay_in_Mins  \
# 98890113             2023                 64.00000               56.00000
# 98854259             4879                160.00000              146.00000
# 98858137             3779                  0.00000                0.00000
# 98823289             1928                  0.00000               20.00000
# 98831835             2331                  2.00000                1.00000
# ...                   ...                      ...                    ...
# 98807581              741                 12.00000                    NaN
# 98886703               87                  0.00000                0.00000
# 98836614               62                  0.00000                0.00000
# 98800530             1227                 14.00000               14.00000
# 98868265              530                  7.00000                5.00000
#
#          Seat_Comfort  Seat_Class Arrival_Time_Convenient Catering  \
# 98890113            1         NaN                       1        2
# 98854259            3         NaN                       5        5
# 98858137            3         NaN                       1        1
# 98823289            5         NaN                       5        5
# 98831835            2         NaN                       2        2
# ...               ...         ...                     ...      ...
# 98807581            4         NaN                       4      NaN
# 98886703            2         NaN                       2        2
# 98836614            3         NaN                       3      NaN
# 98800530            1         NaN                       3      NaN
# 98868265            2         NaN                       4        3
#
#          Platform_Location Onboard_Wifi_Service Onboard_Entertainment  \
# 98890113                 2                    4                     4
# 98854259                 4                    3                     3
# 98858137                 2                    3                     3
# 98823289                 4                    2                     5
# 98831835                 3                    5                     2
# ...                    ...                  ...                   ...
# 98807581                 4                    3                     4
# 98886703                 2                    4                     5
# 98836614                 3                    5                     3
# 98800530                 3                    5                     4
# 98868265                 4                    5                     4
#
#          Online_Support Ease_of_Online_Booking Onboard_Service Legroom  \
# 98890113              5                      5               5       5
# 98854259              3                      1               1       3
# 98858137              3                      3               4       5
# 98823289              2                      2               3       1
# 98831835              5                      5               3       3
# ...                 ...                    ...             ...     ...
# 98807581              5                      4               4       4
# 98886703              3                      4               4       4
# 98836614              5                      2               2       3
# 98800530              4                      1               1       1
# 98868265              4                      2             NaN       2
#
#          Baggage_Handling CheckIn_Service Cleanliness Online_Boarding
# 98890113                5               5           5               5
# 98854259                3               3           4               3
# 98858137                3               2           3               3
# 98823289                4               3           1               2
# 98831835                3               3           3               5
# ...                   ...             ...         ...             ...
# 98807581                4               3           4               5
# 98886703                3               5           4               5
# 98836614                2               1           2               1
# 98800530                1               4           1               3
# 98868265                2               2           2               1
#
# [66065 rows x 23 columns]

# %%
y_train
# Out:
# 98890113    1
# 98854259    0
# 98858137    0
# 98823289    1
# 98831835    0
#            ..
# 98807581    1
# 98886703    1
# 98836614    1
# 98800530    0
# 98868265    0
# Name: Overall_Experience, Length: 66065, dtype: int64

# %%
X_train
# Out:
#           Gender  Customer_Type      Age  Type_Travel  Travel_Class  \
# 98890113 1.00000        1.00000 49.00000      1.00000             1
# 98854259 0.00000        1.00000 45.00000      1.00000             1
# 98858137 1.00000        1.00000 25.00000          NaN             1
# 98823289 0.00000        0.00000 21.00000      1.00000             0
# 98831835 1.00000        0.00000 35.00000          NaN             1
# ...          ...            ...      ...          ...           ...
# 98807581 1.00000        1.00000 57.00000      1.00000             1
# 98886703 1.00000        1.00000 34.00000      1.00000             1
# 98836614 0.00000        1.00000 54.00000      1.00000             0
# 98800530 0.00000        1.00000 35.00000      1.00000             1
# 98868265 0.00000        1.00000 41.00000      1.00000             1
#
#           Travel_Distance  Departure_Delay_in_Mins  Arrival_Delay_in_Mins  \
# 98890113             2023                 64.00000               56.00000
# 98854259             4879                160.00000              146.00000
# 98858137             3779                  0.00000                0.00000
# 98823289             1928                  0.00000               20.00000
# 98831835             2331                  2.00000                1.00000
# ...                   ...                      ...                    ...
# 98807581              741                 12.00000                    NaN
# 98886703               87                  0.00000                0.00000
# 98836614               62                  0.00000                0.00000
# 98800530             1227                 14.00000               14.00000
# 98868265              530                  7.00000                5.00000
#
#          Seat_Comfort  Seat_Class Arrival_Time_Convenient Catering  \
# 98890113            1         NaN                       1        2
# 98854259            3         NaN                       5        5
# 98858137            3         NaN                       1        1
# 98823289            5         NaN                       5        5
# 98831835            2         NaN                       2        2
# ...               ...         ...                     ...      ...
# 98807581            4         NaN                       4      NaN
# 98886703            2         NaN                       2        2
# 98836614            3         NaN                       3      NaN
# 98800530            1         NaN                       3      NaN
# 98868265            2         NaN                       4        3
#
#          Platform_Location Onboard_Wifi_Service Onboard_Entertainment  \
# 98890113                 2                    4                     4
# 98854259                 4                    3                     3
# 98858137                 2                    3                     3
# 98823289                 4                    2                     5
# 98831835                 3                    5                     2
# ...                    ...                  ...                   ...
# 98807581                 4                    3                     4
# 98886703                 2                    4                     5
# 98836614                 3                    5                     3
# 98800530                 3                    5                     4
# 98868265                 4                    5                     4
#
#          Online_Support Ease_of_Online_Booking Onboard_Service Legroom  \
# 98890113              5                      5               5       5
# 98854259              3                      1               1       3
# 98858137              3                      3               4       5
# 98823289              2                      2               3       1
# 98831835              5                      5               3       3
# ...                 ...                    ...             ...     ...
# 98807581              5                      4               4       4
# 98886703              3                      4               4       4
# 98836614              5                      2               2       3
# 98800530              4                      1               1       1
# 98868265              4                      2             NaN       2
#
#          Baggage_Handling CheckIn_Service Cleanliness Online_Boarding
# 98890113                5               5           5               5
# 98854259                3               3           4               3
# 98858137                3               2           3               3
# 98823289                4               3           1               2
# 98831835                3               3           3               5
# ...                   ...             ...         ...             ...
# 98807581                4               3           4               5
# 98886703                3               5           4               5
# 98836614                2               1           2               1
# 98800530                1               4           1               3
# 98868265                2               2           2               1
#
# [66065 rows x 23 columns]

# %%
dt = DecisionTreeClassifier(class_weight = {0: 0.17, 1: 0.83}, random_state = 1)

# %%
dt.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-0498a5200f69> in <module>()
# ----> 1 dt.fit(X_train, y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     940             sample_weight=sample_weight,
#     941             check_input=check_input,
# --> 942             X_idx_sorted=X_idx_sorted,
#     943         )
#     944         return self
#
# /usr/local/lib/python3.7/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     164             check_y_params = dict(ensure_2d=False, dtype=None)
#     165             X, y = self._validate_data(
# --> 166                 X, y, validate_separately=(check_X_params, check_y_params)
#     167             )
#     168             if issparse(X):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     576                 # :(
#     577                 check_X_params, check_y_params = validate_separately
# --> 578                 X = check_array(X, **check_X_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     798
#     799         if force_all_finite:
# --> 800             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     801
#     802     if ensure_min_samples > 0:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     114             raise ValueError(
#     115                 msg_err.format(
# --> 116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#     117                 )
#     118             )
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
np.any(np.isnan(df))

# %%
np.all(np.isfinite(df))

# %%
# Checking performance on the training dataset
y_train_pred_dt = dt.predict(X_train)

metrics_score(y_train, y_train_pred_dt)

# %%
# Checking performance on the test dataset
y_test_pred_dt = dt.predict(X_test)

metrics_score(y_test, y_test_pred_dt)

# %%
importances = dt.feature_importances_

columns = X.columns

importance_df = pd.DataFrame(importances, index = columns, columns = ['Importance']).sort_values(by = 'Importance', ascending = False)

plt.figure(figsize = (13, 13))

sns.barplot(importance_df.Importance,importance_df.index)

# %%
features = list(X.columns)

plt.figure(figsize = (30, 20))

tree.plot_tree(dt, max_depth = 4, feature_names = features, filled = True, fontsize = 12, node_ids = True, class_names = True)

plt.show()

# %%
# Fitting the Random Forest classifier on the training data
rf_estimator = RandomForestClassifier(class_weight = {0: 0.17, 1: 0.83}, random_state = 1)

rf_estimator.fit(X_train, y_train)

# %%
# Checking performance on the training data
y_pred_train_rf = rf_estimator.predict(X_train)

metrics_score(y_train, y_pred_train_rf)

# %%
# Checking performance on the testing data
y_pred_test_rf = rf_estimator.predict(X_test)

metrics_score(y_test, y_pred_test_rf)

# %%
importances = rf_estimator.feature_importances_

columns = X.columns

importance_df = pd.DataFrame(importances, index = columns, columns = ['Importance']).sort_values(by = 'Importance', ascending = False)

plt.figure(figsize = (13, 13))

sns.barplot(importance_df.Importance, importance_df.index)
